# %%
import pandas as pd
import matplotlib.pyplot as plt


''' for ordered list '''
df_insertion_list = pd.read_csv('./csv_orderedlist/insertion.csv', header=0)
df_all_insertion = pd.read_csv('./csv_orderedlist/insertion_all.csv', header=0)
df_search_list = pd.read_csv('./csv_orderedlist/search.csv', header=0)
df_all_search = pd.read_csv('./csv_orderedlist/search_all.csv', header=0)
df_delete_list = pd.read_csv('./csv_orderedlist/delete.csv', header=0)

# ''' BSTcsvs'''
df_delete_BST = pd.read_csv('./csv_bst/delete.csv', header=0)
df_all_search_BST = pd.read_csv('./csv_bst/search_all.csv', header=0)
df_all_insertion_BST = pd.read_csv('./csv_bst/insertion_all.csv', header=0)

# '''BBSTcsvs'''
df_insertion_BBST = pd.read_csv('./csv_bbst/insertion.csv', header=0)
df_search_BBST = pd.read_csv('./csv_bbst/search.csv', header=0)
df_delete_BBST = pd.read_csv('./csv_bbst/delete.csv', header=0)

''' complete following ~~~'''
#df_insertion = pd.read_csv('insertion.csv', header=0)
#df_search = pd.read_csv('search.csv', header=0)
#df_delete = pd.read_csv('delete.csv', header=0)
''' ____________________________________'''

#algo = ["AVL", "BST", "list"]
#insertion_dataframes = [df_insertion.loc[df_insertion['type'] == "AVL"], df_insertion.loc[df_insertion['type'] == "BST"], df_insertion.loc[df_insertion['type'] == "list"]]
#search_dataframes = [df_search.loc[df_search['type'] == "AVL"], df_search.loc[df_search['type'] == "BST"], df_search.loc[df_search['type'] == "list"]]
#delete_dataframes = [df_delete.loc[df_delete['type'] == "AVL"], df_delete.loc[df_delete['type'] == "BST"], df_delete.loc[df_delete['type'] == "list"]]
# Out:
# ' ____________________________________'

# %%
# ordered list
fig = plt.figure()
fig.patch.set_facecolor('xkcd:white') # make transparent background white
plt.plot(df_insertion_list['n'], df_insertion_list['time'], label="insertion")
#plt.plot(df_search_list['n'], df_search_list['time'], label="search")
plt.title("Ordered list - insertion of all n elements")
plt.xlabel('number of elements')
plt.ylabel('time [s]')
plt.legend()
plt.show()

# %%
# ordered list
#df_insertion_list = pd.read_csv('insertion_list.csv', header=0)
fig = plt.figure()
fig.patch.set_facecolor('xkcd:white') # make transparent background white
#plt.plot(df_insertion_list['n'], df_insertion_list['time'], label="insertion")
plt.plot(df_search_list['n'], df_search_list['time'], label="search")
plt.title("Ordered list - search for n elements")
plt.xlabel('number of elements')
plt.ylabel('time [s]')
plt.legend()
plt.show()

# %%
# ordered list
#df_insertion_list = pd.read_csv('insertion_list.csv', header=0)
fig = plt.figure()
fig.patch.set_facecolor('xkcd:white') # make transparent background white
#plt.plot(df_insertion_list['n'], df_insertion_list['time'], label="insertion")
plt.plot(df_delete_list['n'], df_delete_list['time'], label="delete")
plt.title("Ordered list - removing n elements")
plt.xlabel('number of elements')
plt.ylabel('time [s]')
plt.legend()
plt.show()

# %%
''' ************            ordered list          ************  '''
fig = plt.figure()
fig.patch.set_facecolor('xkcd:white') # make transparent background white
#df_insertion_BST.loc[(df_insertion_BST['n'] < max_el)]
max_el=30001
plt.plot(df_all_insertion.loc[(df_all_insertion['n'] < max_el)]['n'], df_all_insertion.loc[(df_all_insertion['n'] < max_el)]['time'], label="insert all", color='purple')
plt.plot(df_all_search.loc[(df_all_search['n'] < max_el)]['n'], df_all_search.loc[(df_all_search['n'] < max_el)]['time'], label="search all", color='red')
plt.plot(df_delete_list['n'], df_delete_list['time'], label="delete all")
plt.title("Ordered list")
plt.xlabel('number of elements')
plt.ylabel('time [s]')
plt.legend()
plt.show()

# %%
# BST
fig = plt.figure()
fig.patch.set_facecolor('xkcd:white') # make transparent background white
plt.plot(df_insertion_BST['n'], df_insertion_BST['time'], label="insertion")
#plt.plot(df_search_BST['n'], df_search_BST['time'], label="search")
plt.title("BST - insertion of n elements")
plt.xlabel('number of elements')
plt.ylabel('time [s]')
plt.legend()
plt.show()

# %%
# BST
fig = plt.figure()
fig.patch.set_facecolor('xkcd:white') # make transparent background white
plt.plot(df_search_BST['n'], df_search_BST['time'], label="search")
#plt.plot(df_search_list['n'], df_search_list['time'], label="search")
plt.title("BST - search for n elements")
plt.xlabel('number of elements')
plt.ylabel('time [s]')
plt.legend()
plt.show()

# %%
# BST
fig = plt.figure()
fig.patch.set_facecolor('xkcd:white') # make transparent background white
plt.plot(df_delete_BST['n'], df_delete_BST['time'], label="delete")
#plt.plot(df_search_list['n'], df_search_list['time'], label="search")
plt.title("BST - deleting n elements")
plt.xlabel('number of elements')
plt.ylabel('time [s]')
plt.legend()
plt.show()

# %%
''' ************            BST          ************  '''
fig = plt.figure()
fig.patch.set_facecolor('xkcd:white') # make transparent background white
max_el=950000
plt.plot(df_all_insertion_BST.loc[(df_all_insertion_BST['n'] < max_el)]['n'], df_all_insertion_BST.loc[(df_all_insertion_BST['n'] < max_el)]['time'], label="insert all")
plt.plot(df_all_search_BST.loc[(df_all_search_BST['n'] < max_el)]['n'], df_all_search_BST.loc[(df_all_search_BST['n'] < max_el)]['time'], label="search all")
plt.plot(df_delete_BST.loc[(df_delete_BST['n'] < max_el)]['n'], df_delete_BST.loc[(df_delete_BST['n'] < max_el)]['time'], label="delete all")
#plt.plot(df_delete_BST['n'], df_delete_BST['time'], label="delete")
plt.title("BST")
plt.xlabel('number of elements')
plt.ylabel('time [s]')
plt.legend()
plt.show()

# %%
# INSERTION
fig = plt.figure()
fig.patch.set_facecolor('xkcd:white') # make transparent background white
max_el = 51002
plt.plot(df_insertion_BBST.loc[(df_insertion_BBST['n'] < max_el)]['n'], df_insertion_BBST.loc[(df_insertion_BBST['n'] < max_el)]['time'], label="BBST")
plt.plot(df_all_insertion_BST.loc[(df_all_insertion_BST['n'] < max_el)]['n'], df_all_insertion_BST.loc[(df_all_insertion_BST['n'] < max_el)]['time'], label="BST")
plt.plot(df_insertion_list['n'], df_insertion_list['time'], label="list")
#plt.plot(df_delete_BST['n'], df_delete_BST['time'], label="delete")
plt.title("Insertion time of all n elements\nfor ordered list, BST and BBST")
plt.xlabel('number of elements')
plt.ylabel('time [s]')
plt.legend()
plt.show()

# %%
# SEARCH
fig = plt.figure()
fig.patch.set_facecolor('xkcd:white') # make transparent background white
max_el = 40000
plt.plot(df_search_BBST.loc[(df_search_BBST['n'] < max_el)]['n'], df_search_BBST.loc[(df_search_BBST['n'] < max_el)]['time'], label="BBST")
plt.plot(df_all_search_BST.loc[(df_all_search_BST['n'] < max_el)]['n'], df_all_search_BST.loc[(df_all_search_BST['n'] < max_el)]['time'], label="BST")
#df_withoutBS.loc[df_withoutBS['type'] == "HS"]
plt.plot(df_all_search['n'], df_all_search['time'], label="list")
#plt.plot(df_delete_BST['n'], df_delete_BST['time'], label="delete")
plt.title("Searching n elemets\nusing ordered list, BST and BBST")
plt.xlabel('number of elements')
plt.ylabel('time [s]')
plt.legend()
plt.show()

# %%
# SEARCH
fig = plt.figure()
fig.patch.set_facecolor('xkcd:white') # make transparent background white
max_el = 4000000000
plt.plot(df_search_BBST.loc[(df_search_BBST['n'] < max_el)]['n'], df_search_BBST.loc[(df_search_BBST['n'] < max_el)]['time'], label="BBST")
plt.plot(df_all_search_BST.loc[(df_all_search_BST['n'] < max_el)]['n'], df_all_search_BST.loc[(df_all_search_BST['n'] < max_el)]['time'], label="BST")
#df_withoutBS.loc[df_withoutBS['type'] == "HS"]
#plt.plot(df_all_search['n'], df_all_search['time'], label="list")
#plt.plot(df_delete_BST['n'], df_delete_BST['time'], label="delete")
plt.title("Searching n elemets\nusing BST and BBST")
plt.xlabel('number of elements')
plt.ylabel('time [s]')
plt.legend()
plt.show()

# %%
# DELETION
fig = plt.figure()
fig.patch.set_facecolor('xkcd:white') # make transparent background white
max_el = 400000002
plt.plot(df_delete_BBST.loc[(df_delete_BBST['n'] < max_el)]['n'], df_delete_BBST.loc[(df_delete_BBST['n'] < max_el)]['time'], label="BBST")
plt.plot(df_delete_BST.loc[(df_delete_BST['n'] < max_el)]['n'], df_delete_BST.loc[(df_delete_BST['n'] < max_el)]['time'], label="BST")
#plt.plot(df_delete_list['n'], df_delete_list['time'], label="list")
#plt.plot(df_delete_BST['n'], df_delete_BST['time'], label="delete")
plt.title("Delete all n elemets")
plt.xlabel('number of elements')
plt.ylabel('time [s]')
plt.legend()
plt.show()

# %%
''' BALANCED BST '''
fig = plt.figure()
fig.patch.set_facecolor('xkcd:white') # make transparent background white
max_el = 220002
plt.plot(df_delete_BBST.loc[(df_delete_BBST['n'] < max_el)]['n'], df_delete_BBST.loc[(df_delete_BBST['n'] < max_el)]['time'], label="BBST")
plt.plot(df_delete_BST.loc[(df_delete_BST['n'] < max_el)]['n'], df_delete_BST.loc[(df_delete_BST['n'] < max_el)]['time'], label="BST")
#plt.plot(df_delete_BBST['n'], df_delete_BBST['time'], label="BBST")
#plt.plot(df_delete_BST['n'], df_delete_BST['time'], label="delete")
plt.title("Delete")
plt.xlabel('number of elements')
plt.ylabel('time [s]')
plt.legend()
plt.show()

# %%
''' BALANCED BST insertion '''
fig = plt.figure()
fig.patch.set_facecolor('xkcd:white') # make transparent background white
max_el = 400002
plt.plot(df_insertion_BBST.loc[(df_insertion_BBST['n'] < max_el)]['n'], df_insertion_BBST.loc[(df_insertion_BBST['n'] < max_el)]['time'], label="BBST")
plt.plot(df_insertion_BST.loc[(df_insertion_BST['n'] < max_el)]['n'], df_insertion_BST.loc[(df_insertion_BST['n'] < max_el)]['time'], label="BST")
#plt.plot(df_insertion_BBST['n'], df_insertion_BBST['time'], label="BBST")
#plt.plot(df_delete_BST['n'], df_delete_BST['time'], label="delete")
plt.title("insertion")
plt.xlabel('number of elements')
plt.ylabel('time [s]')
plt.legend()
plt.show()

# %%
''' BALANCED BST search '''
fig = plt.figure()
fig.patch.set_facecolor('xkcd:white') # make transparent background white
max_el = 160002
plt.plot(df_search_BBST.loc[(df_search_BBST['n'] < max_el)]['n'], df_search_BBST.loc[(df_search_BBST['n'] < max_el)]['time'], label="BBST")
plt.plot(df_search_BST.loc[(df_search_BST['n'] < max_el)]['n'], df_search_BST.loc[(df_search_BST['n'] < max_el)]['time'], label="BST")
plt.title("search")
plt.xlabel('number of elements')
plt.ylabel('time [s]')
plt.legend()
plt.show()

# %%
''' ************            BBST          ************  '''
fig = plt.figure()
fig.patch.set_facecolor('xkcd:white') # make transparent background white
max_el=160001000
plt.plot(df_insertion_BBST.loc[(df_insertion_BBST['n'] < max_el)]['n'], df_insertion_BBST.loc[(df_insertion_BBST['n'] < max_el)]['time'], label="insert all")
plt.plot(df_search_BBST.loc[(df_search_BBST['n'] < max_el)]['n'], df_search_BBST.loc[(df_search_BBST['n'] < max_el)]['time'], label="search all")
plt.plot(df_delete_BBST.loc[(df_delete_BBST['n'] < max_el)]['n'], df_delete_BBST.loc[(df_delete_BBST['n'] < max_el)]['time'], label="delete all")
#plt.plot(df_delete_BBST['n'], df_delete_BBST['time'], label="delete")
plt.title("BBST")
plt.xlabel('number of elements')
plt.ylabel('time [s]')
plt.legend()
plt.show()
